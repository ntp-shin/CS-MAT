stat_uids_cswintv62 = np.array(uids_cswintv62[(16+15+15):len(uids_cswintv62)//15*15+1]).reshape(-1, 15)

# %%
plt.figure(figsize=(18, 9))
low_bound = 46
high_bound = max(len(fid_org), len(fid_cswintv43), len(fid_cswintv62))
# high_bound = 16

show_models = '111'

for i, (org, cswintv43, cswintv62) in enumerate([(fid_org, fid_cswintv43, fid_cswintv62), (pids_org, pids_cswintv43, pids_cswintv62), (uids_org, uids_cswintv43, uids_cswintv62)]):
    ax = plt.subplot(3, 1, i+1)
    ax.set_yscale('log')
    if i == 0:
        ax.set_ylabel('log(FID)')
    elif i == 1:
        ax.set_ylabel('log(PIDS)')
    else:
        ax.set_ylabel('log(UIDS)')
    ax.set_xlabel('kimg')

    if show_models[0] == '1':
        kimg_org = np.arange(0, len(org)*40, 40)
        ax.plot(kimg_org[low_bound:high_bound], org[low_bound:high_bound], label='Org-b8', color='black')

    if show_models[1] == '1':
        kimg_cswintv43 = np.arange(0, len(cswintv43)*40, 40)
        ax.plot(kimg_cswintv43[low_bound:high_bound], cswintv43[low_bound:high_bound], label='CSWinT-b8-v4.3', color='green')

    if show_models[2] == '1':
        kimg_cswintv62 = np.arange(0, len(cswintv62)*40, 40)
        ax.plot(kimg_cswintv62[low_bound:high_bound], cswintv62[low_bound:high_bound], label='CSWinT-b8-v6.2', color='blue')
        
    ax.legend()

# %%
high_bound = min(len(fid_org), len(fid_cswintv43), len(fid_cswintv62))
# high_bound = 16 + 15*5
print('fid\t\t', 'best\t\t', 'last')
print('org-b8\t\t', min(fid_org[:high_bound]), fid_org[:high_bound][-1])
print('cswint-b8-v4.3\t', min(fid_cswintv43[:high_bound]), fid_cswintv43[:high_bound][-1])
print('cswint-b8-v6.2\t', min(fid_cswintv62[:high_bound]), fid_cswintv62[:high_bound][-1])
print('\npids\t\t', 'best\t\t', 'last')
print('org-b8\t\t', max(pids_org[:high_bound]), pids_org[:high_bound][-1])
print('cswint-b8-v4.3\t', max(pids_cswintv43[:high_bound]), pids_cswintv43[:high_bound][-1])
print('cswint-b8-v6.2\t', max(pids_cswintv62[:high_bound]), pids_cswintv62[:high_bound][-1])
print('\nuids\t\t', 'best\t\t', 'last')
print('org-b8\t\t', max(uids_org[:high_bound]), uids_org[:high_bound][-1])
print('cswint-b8-v4.3\t', max(uids_cswintv43[:high_bound]), uids_cswintv43[:high_bound][-1])
print('cswint-b8-v6.2\t', max(uids_cswintv62[:high_bound]), uids_cswintv62[:high_bound][-1])
# Out:
# fid		 best		 last
# org-b8		 4.77485785 4.906425384
# cswint-b8-v4.3	 4.78487664 4.906316158
# cswint-b8-v6.2	 4.786800568 5.012253666
#
# pids		 best		 last
# org-b8		 0.146675576 0.137654527
# cswint-b8-v4.3	 0.139325092 0.120948881
# cswint-b8-v6.2	 0.148680254 0.136652188
#
# uids		 best		 last
# org-b8		 0.25943869 0.254594053
# cswint-b8-v4.3	 0.254426996 0.231540261
# cswint-b8-v6.2	 0.263448045 0.246909455

# %%
density = False
org_labels = []
plt.figure(figsize=(18, len(stat_fid_org)*2))

for i in range(len(stat_fid_org)):
    org_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')

    for j, org in enumerate([stat_fid_org, stat_pids_org, stat_uids_org]):
        org_ax = plt.subplot(len(org), 3, i*3+j+1)
        org_ax.set_ylim(0, 8)
        if j == 0:
            bin_interval = np.linspace(4.6, 5.5, 15)
            org_ax.set_xlabel('fid')
            org_ax.set_ylabel(org_labels[-1])
        elif j == 1:
            bin_interval = np.linspace(.1, .17, 15)
            org_ax.set_xlabel('pids')
        else:
            bin_interval = np.linspace(.21, .27, 15)
            org_ax.set_xlabel('uids')
        
        org_ax.hist(org[i], bins=bin_interval, density=density)

# %%
density = False
cswintv43_labels = []
plt.figure(figsize=(18, len(stat_fid_cswintv43)*2))

for i in range(len(stat_fid_cswintv43)):
    cswintv43_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')

    for j, cswintv43 in enumerate([stat_fid_cswintv43, stat_pids_cswintv43, stat_uids_cswintv43]):
        cswintv43_ax = plt.subplot(len(cswintv43), 3, i*3+j+1)
        cswintv43_ax.set_ylim(0, 10)
        if j == 0:
            bin_interval = np.linspace(4.6, 5.5, 15)
            cswintv43_ax.set_xlabel('fid')
            cswintv43_ax.set_ylabel(cswintv43_labels[-1])
        elif j == 1:
            bin_interval = np.linspace(.1, .17, 15)
            cswintv43_ax.set_xlabel('pids')
        else:
            bin_interval = np.linspace(.21, .27, 15)
            cswintv43_ax.set_xlabel('uids')
        
        cswintv43_ax.hist(cswintv43[i], bins=bin_interval, density=density)

# %%
density = False
cswintv62_labels = []
plt.figure(figsize=(18, len(stat_fid_cswintv62)*2))

for i in range(len(stat_fid_cswintv62)):
    cswintv62_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')

    for j, cswintv62 in enumerate([stat_fid_cswintv62, stat_pids_cswintv62, stat_uids_cswintv62]):
        cswintv62_ax = plt.subplot(len(cswintv62), 3, i*3+j+1)
        cswintv62_ax.set_ylim(0, 10)
        if j == 0:
            bin_interval = np.linspace(4.6, 5.5, 15)
            cswintv62_ax.set_xlabel('fid')
            cswintv62_ax.set_ylabel(cswintv62_labels[-1])
        elif j == 1:
            bin_interval = np.linspace(.1, .17, 15)
            cswintv62_ax.set_xlabel('pids')
        else:
            bin_interval = np.linspace(.21, .27, 15)
            cswintv62_ax.set_xlabel('uids')
        
        cswintv62_ax.hist(cswintv62[i], bins=bin_interval, density=density)

# %%
vert = False
plt.figure(figsize=(18, len(stat_fid_org)))

for i, org in enumerate([stat_fid_org, stat_pids_org, stat_uids_org]):
    ax = plt.subplot(1, 3, i+1)
    if i == 0:
        ax.set_xlim(4.6, 5.5)
        ax.set_xlabel('fid')
        ax.set_ylabel('O-b8')
    elif i == 1:
        ax.set_xlim(.09, .17)
        ax.set_xlabel('pids')
    else:
        ax.set_xlim(.2, .27)
        ax.set_xlabel('uids')

    if i == 0:
        ax.boxplot(list(org[::-1]), vert=vert, labels=org_labels[::-1])
    else:
        ax.boxplot(list(org[::-1]), vert=vert)

# %%
vert = False
plt.figure(figsize=(18, len(stat_fid_cswintv43)))

for i, cswintv43 in enumerate([stat_fid_cswintv43, stat_pids_cswintv43, stat_uids_cswintv43]):
    ax = plt.subplot(1, 3, i+1)
    if i == 0:
        ax.set_xlim(4.6, 5.5)
        ax.set_xlabel('fid')
        ax.set_ylabel('C-b8-v4.3')
    elif i == 1:
        ax.set_xlim(.09, .17)
        ax.set_xlabel('pids')
    else:
        ax.set_xlim(.2, .27)
        ax.set_xlabel('uids')

    if i == 0:
        ax.boxplot(list(cswintv43[::-1]), vert=vert, labels=cswintv43_labels[::-1])
    else:
        ax.boxplot(list(cswintv43[::-1]), vert=vert)

# %%
vert = False
plt.figure(figsize=(18, len(stat_fid_cswintv62)))

for i, cswintv62 in enumerate([stat_fid_cswintv62, stat_pids_cswintv62, stat_uids_cswintv62]):
    ax = plt.subplot(1, 3, i+1)
    if i == 0:
        ax.set_xlim(4.6, 5.5)
        ax.set_xlabel('fid')
        ax.set_ylabel('C-b8-v6.2')
    elif i == 1:
        ax.set_xlim(.09, .17)
        ax.set_xlabel('pids')
    else:
        ax.set_xlim(.2, .27)
        ax.set_xlabel('uids')

    if i == 0:
        ax.boxplot(list(cswintv62[::-1]), vert=vert, labels=cswintv62_labels[::-1])
    else:
        ax.boxplot(list(cswintv62[::-1]), vert=vert)

# %%
vert = False
nrow = max(len(stat_fid_org), len(stat_fid_cswintv43), len(stat_fid_cswintv62))
plt.figure(figsize=(18, nrow*2))

for i in range(nrow):
    for j in range(3):
        ax = plt.subplot(nrow, 3, i*3+j+1)
        if j == 0:
            ax.set_xlim(4.6, 5.5)
            ax.set_xlabel('fid')
            ax.set_ylabel(cswintv62_labels[i])
        elif j == 1:
            ax.set_xlim(.09, .17)
            ax.set_xlabel('pids')
        else:
            ax.set_xlim(.2, .27)
            ax.set_xlabel('uids')

        org, cswintv43, cswintv62 = [[5.]*15, [.13]*15, [.24]*15], [[5.]*15, [.13]*15, [.24]*15], [[5.]*15, [.13]*15, [.24]*15]
        for k, (o, cv43, cv62) in enumerate([(stat_fid_org, stat_fid_cswintv43, stat_fid_cswintv62), (stat_pids_org, stat_pids_cswintv43, stat_pids_cswintv62), (stat_uids_org, stat_uids_cswintv43, stat_uids_cswintv62)]):
            if i < len(o):
                org[k] = o[i]
            if i < len(cv43):
                cswintv43[k] = cv43[i]
            if i < len(cv62):
                cswintv62[k] = cv62[i]

        if i == 0 and j == 0:
            ax.boxplot(list([org[j], cswintv43[j], cswintv62[j]])[::-1], vert=vert, labels=['O-b8', 'C-b8-v4.3', 'C-b8-v6.2'][::-1])
            ax.set_yticklabels(ax.get_yticklabels(), rotation=60)
        else:
            ax.boxplot(list([org[j], cswintv43[j], cswintv62[j]])[::-1], vert=vert)
