# %%
cswinv41 = [173.7522603,129.5565884,27.91897893,16.40951272,12.13977902,10.74485937,9.400237174,8.43669452,7.98333379,7.363098873,7.170611772,6.790182505,6.679735882,6.440465612,6.355081332,6.153725177,
            6.251477509,5.961871528,5.868957002,5.902157253,5.893363353,5.787035445,5.671416923,5.556798092,5.563337991,5.379884872,5.536700252,5.426929103,5.553903857,5.534456086,5.323871737]
cswinv6 = [169.5365574,143.1589844,39.4921819,16.43341426,12.04145943,9.958834286,8.495124186,7.847497296,7.370476114,6.817786123,6.475940397,6.509412853,6.473192557,6.401595017,6.142124899,6.144540759,
           6.006836507,5.895203356,6.104032091,5.811571673,5.782031924,5.765527875,5.563108272,5.5458515,5.474378472,5.499192529,5.480060522,5.43259932,5.370570961,5.373855919,5.218385202]
cswinv61 = [169.7030975,128.867231,40.55330883,20.54981373,13.85070832,11.50229812,9.633319494,8.915717653,8.066883759,7.244761219,7.023204911,6.878563322,6.670932766,6.405078646,6.103646086,6.192797663]

# %%
plt.figure(figsize=(15, 4))
plt.yscale('log')
plt.ylabel('log(FID)')
plt.xlabel('kimg')
lim_kimg = len(full_org8)
# lim_kimg = 16 + 15*7

show_models = '00101'

# kimg_cmat16 = np.arange(0, len(full_cmat16)*40, 40)
# plt.plot(kimg_cmat16[16:], full_cmat16[16:], label='CMAT-b16')

# kimg_cmat8 = np.arange(0, len(full_cmat8)*40, 40)
# plt.plot(kimg_cmat8[16:], full_cmat8[16:], label='CMAT-b8', color='goldenrod')

if show_models[0] == '1':
    kimg_cswint8v4 = np.arange(0, len(full_cswint8v4)*40, 40)
    plt.plot(kimg_cswint8v4[16:lim_kimg], full_cswint8v4[16:lim_kimg], label='CSWinT-b8-v4', color='red')

if show_models[1] == '1':
    kimg_cswint8 = np.arange(0, len(full_cswint8)*40, 40)
    plt.plot(kimg_cswint8[16:lim_kimg], full_cswint8[16:lim_kimg], label='CSWinT-b8-v6', color='green')

if show_models[2] == '1':
    kimg_cswint8v62 = np.arange(0, len(full_cswint8v62)*40, 40)
    plt.plot(kimg_cswint8v62[16:lim_kimg], full_cswint8v62[16:lim_kimg], label='CSWinT-b8-v6.2', color='blue')

if show_models[3] == '1':
    kimg_cswint8v63 = np.arange(0, len(full_cswint8v63)*40, 40)
    plt.plot(kimg_cswint8v63[16:lim_kimg], full_cswint8v63[16:lim_kimg], label='CSWinT-b8-v6.3', color='yellow')

if show_models[4] == '1':
    kimg_org8 = np.arange(0, len(full_org8)*40, 40)
    plt.plot(kimg_org8[16:], full_org8[16:], label='Org-b8', color='black')

# kimg_org16 = np.arange(0, len(full_org16)*40, 40)
# plt.plot(kimg_org16[16:lim_kimg], full_org16[16:lim_kimg], label='Org-b16', color='magenta')

plt.legend()

# %%
lim_kimg = len(full_cswint8v62)
# lim_kimg = 16 + 15*5
print('\t\t', 'best\t\t', 'last')
print('org-b16\t\t', min(full_org16[:lim_kimg]), full_org16[:lim_kimg][-1])
print('org-b8\t\t', min(full_org8[:lim_kimg]), full_org8[:lim_kimg][-1])
print('cswint-b8-v4\t', min(full_cswint8v4[:lim_kimg]), full_cswint8v4[:lim_kimg][-1])
print('cswint-b8-v6\t', min(full_cswint8[:lim_kimg]), full_cswint8[:lim_kimg][-1])
print('cswint-b8-v6.2\t', min(full_cswint8v62[:lim_kimg]), full_cswint8v62[:lim_kimg][-1])
print('cswint-b8-v6.3\t', min(full_cswint8v63[:lim_kimg]), full_cswint8v63[:lim_kimg][-1])
# print('cmat-b8\t\t', min(full_cmat8[:lim_kimg]), full_cmat8[:lim_kimg][-1])
# print('cmat-b16\t', min(full_cmat16[:lim_kimg]), full_cmat16[:lim_kimg][-1])
# Out:
# 		 best		 last
# org-b16		 4.806764087 4.965101854
# org-b8		 4.742349563 4.926744858
# cswint-b8-v4	 4.762436201 4.884118849
# cswint-b8-v6	 4.751782339 4.916610535
# cswint-b8-v6.2	 4.790446194 4.825352163
# cswint-b8-v6.3	 4.866951663 5.086805472

# %%
new_train_cmat8 = 0
new_train_cswint8v4 = 0
new_train_cswint8 = 0
new_train_cswint8v62 = 0
new_train_cswint8v63 = 0
new_train_org8 = 0
new_train_org16 = 0

plt.figure(figsize=(15, 4))

# plt.plot(np.arange(40*15*3, kimg_cmat8[-1], 40), stat_cmat8.reshape(-1), label='CMAT-b8', color='goldenrod')
# if new_train_cmat8:
#     plt.plot(np.arange(kimg_cmat8[-1] - new_train_cmat8*15*40, kimg_cmat8[-1], 40), stat_cmat8.reshape(-1)[-(new_train_cmat8*15):], color='darkgoldenrod')

show_models = '01000'

if show_models[0] == '1':
    plt.plot(np.arange(40*15*3, kimg_cswint8v4[-1], 40), full_cswint8v4[16+15*2:], label='CSWinT-b8-v4', color='red')
    if new_train_cswint8v4:
        plt.plot(np.arange(kimg_cswint8v4[-1] - new_train_cswint8v4*15*40, kimg_cswint8v4[-1], 40), full_cswint8v4[16+15*2:][-(new_train_cswint8v4*15):], color='darkred')

if show_models[1] == '1':
    plt.plot(np.arange(40*15*3, kimg_cswint8[-1], 40), full_cswint8[16+15*2:], label='CSWinT-b8-v6', color='green')
    if new_train_cswint8:
        plt.plot(np.arange(kimg_cswint8[-1] - new_train_cswint8*15*40, kimg_cswint8[-1], 40), full_cswint8[16+15*2:][-(new_train_cswint8*15):], color='darkgreen')

if show_models[2] == '1':
    plt.plot(np.arange(40*15*3, kimg_cswint8v62[-1], 40), full_cswint8v62[16+15*2:], label='CSWinT-b8-v6.2', color='blue')
    if new_train_cswint8v62:
        plt.plot(np.arange(kimg_cswint8v62[-1] - new_train_cswint8v62*15*40, kimg_cswint8v62[-1], 40), full_cswint8v62[16+15*2:][-(new_train_cswint8v62*15):], color='darkblue')

if show_models[3] == '1':
    plt.plot(np.arange(40*15*3, kimg_cswint8v63[-1], 40), full_cswint8v63[16+15*2:], label='CSWinT-b8-v6.3', color='yellow')
    if new_train_cswint8v63:
        plt.plot(np.arange(kimg_cswint8v63[-1] - new_train_cswint8v63*15*40, kimg_cswint8v63[-1], 40), full_cswint8v63[16+15*2:][-(new_train_cswint8v63*15):], color='darkyellow')

if show_models[4] == '1':
    plt.plot(np.arange(40*15*3, kimg_org8[-1], 40), full_org8[16+15*2:], label='Org-b8', color='black')
    if new_train_org8:
        plt.plot(np.arange(kimg_org8[-1] - new_train_org8*15*40, kimg_org8[-1], 40), full_org8[16+15*2:][-(new_train_org8*15):], color='black')

# plt.plot(np.arange(40*15*3, kimg_org16[-1], 40), stat_org16.reshape(-1), label='Org-b16', color='magenta')
# if new_train_org16:
#     plt.plot(np.arange(kimg_org16[-1] - new_train_org16*15*40, kimg_org16[-1], 40), stat_org16.reshape(-1)[-(new_train_org16*15):], color='darkmagenta')

plt.legend()

# %%
bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
density = False
org16_labels = []
nrow = int(np.ceil(len(stat_org16)/5))
plt.figure(figsize=(15, nrow*3))

for i, org16 in enumerate(stat_org16):
    org16_ax = plt.subplot(nrow, 5, i+1)
    org16_ax.set_ylim(0, 10)
    
    org16_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
    plt.hist(org16, bins=bin_interval, density=density, label=org16_labels[-1])
    plt.legend()

# %%
bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
density = False
org8_labels = []
nrow = int(np.ceil(len(stat_org8)/5))
plt.figure(figsize=(15, nrow*3))

for i, org8 in enumerate(stat_org8):
    org8_ax = plt.subplot(nrow, 5, i+1)
    org8_ax.set_ylim(0, 10)
    
    org8_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
    plt.hist(org8, bins=bin_interval, density=density, label=org8_labels[-1])
    plt.legend()

# %%
bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
density = False
cswint8v4_labels = []
nrow = int(np.ceil(len(stat_cswint8v4)/5))
plt.figure(figsize=(15, nrow*3))

for i, cswint8v4 in enumerate(stat_cswint8v4):
    cswint8v4_ax = plt.subplot(nrow, 5, i+1)
    cswint8v4_ax.set_ylim(0, 10)
    
    cswint8v4_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
    plt.hist(cswint8v4, bins=bin_interval, density=density, label=cswint8v4_labels[-1])
    plt.legend()

# %%
bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
density = False
cswint8_labels = []
nrow = int(np.ceil(len(stat_cswint8)/5))
plt.figure(figsize=(15, nrow*3))

for i, cswint8 in enumerate(stat_cswint8):
    cswint8_ax = plt.subplot(nrow, 5, i+1)
    cswint8_ax.set_ylim(0, 10)
    
    cswint8_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
    plt.hist(cswint8, bins=bin_interval, density=density, label=cswint8_labels[-1])
    plt.legend()

# %%
bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
density = False
cswint8v62_labels = []
nrow = int(np.ceil(len(stat_cswint8v62)/5))
plt.figure(figsize=(15, nrow*3))

for i, cswint8v62 in enumerate(stat_cswint8v62):
    cswint8v62_ax = plt.subplot(nrow, 5, i+1)
    cswint8v62_ax.set_ylim(0, 10)
    
    cswint8v62_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
    plt.hist(cswint8v62, bins=bin_interval, density=density, label=cswint8v62_labels[-1])
    plt.legend()

# %%
bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
density = False
cswint8v63_labels = []
nrow = int(np.ceil(len(stat_cswint8v63)/5))
plt.figure(figsize=(15, nrow*3))

for i, cswint8v63 in enumerate(stat_cswint8v63):
    cswint8v63_ax = plt.subplot(nrow, 5, i+1)
    cswint8v63_ax.set_ylim(0, 10)
    
    cswint8v63_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
    plt.hist(cswint8v63, bins=bin_interval, density=density, label=cswint8v63_labels[-1])
    plt.legend()

# %%
# bin_interval = [4.6, 4.7, 4.8, 4.9, 5.0, 5.1, 5.2, 5.3, 5.4, 5.5, 5.6, 5.7, 5.8, 5.9, 6.0]
# density = False
# cmat8_labels = []
# nrow = int(np.ceil(len(stat_cmat8)/5))
# plt.figure(figsize=(15, nrow*3))

# for i, cmat8 in enumerate(stat_cmat8):
#     cmat8_ax = plt.subplot(nrow, 5, i+1)
#     cmat8_ax.set_ylim(0, 10)
    
#     cmat8_labels.append(f'{1800+600*(i)}:{1800+600*(i+1)}')
#     plt.hist(cmat8, bins=bin_interval, density=density, label=cmat8_labels[-1])
#     plt.legend()

# %%
boxes = stat_org16[::-1]
vert = False

plt.figure(figsize=(15, len(stat_org16)))
plt.xlim(4.6, 6.0)
plt.boxplot(list(boxes), vert=vert, labels=org16_labels[::-1]);

# %%
boxes = stat_org8[::-1]
vert = False

plt.figure(figsize=(15, len(stat_org8)))
plt.xlim(4.6, 6.0)
plt.boxplot(list(boxes), vert=vert, labels=org8_labels[::-1]);

# %%
boxes = stat_cswint8v4[::-1]
vert = False

plt.figure(figsize=(15, len(stat_cswint8v4)))
plt.xlim(4.6, 6.0)
plt.boxplot(list(boxes), vert=vert, labels=cswint8v4_labels[::-1]);

# %%
boxes = stat_cswint8[::-1]
vert = False

plt.figure(figsize=(15, len(stat_cswint8)))
plt.xlim(4.6, 6.0)
plt.boxplot(list(boxes), vert=vert, labels=cswint8_labels[::-1]);

# %%
boxes = stat_cswint8v62[::-1]
vert = False

plt.figure(figsize=(15, len(stat_cswint8v62)))
plt.xlim(4.6, 6.0)
plt.boxplot(list(boxes), vert=vert, labels=cswint8v62_labels[::-1]);

# %%
boxes = stat_cswint8v63[::-1]
vert = False

plt.figure(figsize=(15, len(stat_cswint8v63)))
plt.xlim(4.6, 6.0)
plt.boxplot(list(boxes), vert=vert, labels=cswint8v63_labels[::-1]);

# %%
# boxes = stat_cmat8[::-1]
# vert = False

# plt.figure(figsize=(15, len(stat_cmat8)))
# plt.xlim(4.6, 6.0)
# plt.boxplot(list(boxes), vert=vert, labels=cmat8_labels[::-1]);

# %%
# nrow = int(np.ceil(len(stat_cmat8)/5))
# plt.figure(figsize=(15, nrow*5))

# for i, (org16, org8, cswint8, cmat8) in enumerate(zip(stat_org16, stat_org8, stat_cswint8, stat_cmat8)):
#     ax = plt.subplot(nrow, 5, i+1)
#     ax.set_ylim(4.6, 5.8)
#     ax.set_xlabel(org16_labels[i])
#     plt.boxplot(list([org16, org8, cswint8, cmat8]), vert=True, labels=['Org-b16', 'Org-b8', 'CSWinT-b8', 'CMAT-b8'])
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
vert = True

plt.figure(figsize=(len(stat_org16), 5))
plt.ylim(4.6, 5.7)
plt.boxplot(list(stat_org16), vert=vert, labels=org16_labels);

# %%
vert = True

plt.figure(figsize=(len(stat_org8), 5))
plt.ylim(4.6, 5.4)
plt.boxplot(list(stat_org8), vert=vert, labels=org8_labels);

# %%
vert = True

plt.figure(figsize=(len(stat_cswint8v4), 5))
plt.ylim(4.6, 5.4)
plt.boxplot(list(stat_cswint8v4), vert=vert, labels=cswint8v4_labels);

# %%
vert = True

plt.figure(figsize=(len(stat_cswint8), 5))
plt.ylim(4.6, 5.4)
plt.boxplot(list(stat_cswint8), vert=vert, labels=cswint8_labels);

# %%
vert = True

plt.figure(figsize=(len(stat_cswint8v62), 5))
plt.ylim(4.6, 5.4)
plt.boxplot(list(stat_cswint8v62), vert=vert, labels=cswint8v62_labels);

# %%
vert = True

plt.figure(figsize=(len(stat_cswint8v63), 5))
plt.ylim(4.6, 5.4)
plt.boxplot(list(stat_cswint8v63), vert=vert, labels=cswint8v63_labels);

# %%
nrow = int(np.ceil(len(stat_cswint8)/5))
plt.figure(figsize=(15, nrow*6))

for i, cswint8 in enumerate(stat_cswint8):
    ax = plt.subplot(nrow, 5, i+1)
    ax.set_ylim(4.6, 5.8)
    ax.set_xlabel(cswint8_labels[i])

    org16, org8, cswint8v4, cswint8v62, cswint8v63 = [5.]*15, [5.]*15, [5.]*15, [5.]*15, [5.]*15
    if i < len(stat_org16):
        org16 = stat_org16[i]
    if i < len(stat_org8):
        org8 = stat_org8[i]
    if i < len(stat_cswint8v4):
        cswint8v4 = stat_cswint8v4[i]
    if i < len(stat_cswint8v62):
        cswint8v62 = stat_cswint8v62[i]
    if i < len(stat_cswint8v63):
        cswint8v63 = stat_cswint8v63[i]

    plt.boxplot(list([org16, org8, cswint8v4, cswint8, cswint8v62, cswint8v63]), vert=True, labels=['O-b16', 'O-b8', 'C-v4', 'C-v6', 'C-v6.2', 'C-v6.3'])
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
begin = 106
end = 119

plt.boxplot([full_org16[begin:end], full_org8[begin:end], full_cswint8v4[begin:end], full_cswint8[begin:end], full_cswint8v62[begin:end], full_cswint8v63[begin:end]], labels=['org-b16', 'org-b8', 'cswint-v4', 'cswint-v6', 'cswint-v6.2', 'cswint-v6.3']);

# %%
# nrow = int(np.ceil(len(stat_org16)/5))
# plt.figure(figsize=(15, nrow*5))

# for i, (org16, cswint8) in enumerate(zip(stat_org16, stat_cswint8)):
#     ax = plt.subplot(nrow, 5, i+1)
#     ax.set_ylim(4.6, 5.8)
#     ax.set_xlabel(org16_labels[i])
#     plt.boxplot(list([org16, cswint8]), vert=True, labels=['Org-b16', 'CSWinT-b8'])
